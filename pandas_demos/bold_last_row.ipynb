# %%
from IPython.core.display_functions import display
import pandas as pd

def df_style(val):
    return "font-weight: bold"

summary = pd.DataFrame([[0, 0, 0, 0, 0], [1620, 203, 392, 651, 2236],[2,0,1,4,3]],
                       index=["InvesterModel","All Projects", "Quant MDP"])

summary.columns =['Jan', 'Feb','Mar','Apr','May']
# get a handle on the row that starts with `"Total"`, i.e., the last row here
last_row = pd.IndexSlice[summary.index[summary.index == "All Projects"], :]
# and apply styling to it via the `subset` arg; first arg is styler function above
summaryStyled = summary.style.applymap(df_style, subset=last_row)

display(summaryStyled)

##############################################way2
last_row = pd.IndexSlice[implementation_df.index[implementation_df.index == 5], :]
imp_styled_df =implementation_df.style.applymap(df_style, subset=last_row)
display(imp_styled_df)
# Out:
# <style type="text/css">
# #T_0ad53_row1_col0, #T_0ad53_row1_col1, #T_0ad53_row1_col2, #T_0ad53_row1_col3, #T_0ad53_row1_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0ad53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ad53_level0_col0" class="col_heading level0 col0" >Jan</th>
#       <th id="T_0ad53_level0_col1" class="col_heading level0 col1" >Feb</th>
#       <th id="T_0ad53_level0_col2" class="col_heading level0 col2" >Mar</th>
#       <th id="T_0ad53_level0_col3" class="col_heading level0 col3" >Apr</th>
#       <th id="T_0ad53_level0_col4" class="col_heading level0 col4" >May</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ad53_level0_row0" class="row_heading level0 row0" >InvesterModel</th>
#       <td id="T_0ad53_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0ad53_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0ad53_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0ad53_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0ad53_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0ad53_level0_row1" class="row_heading level0 row1" >All Projects</th>
#       <td id="T_0ad53_row1_col0" class="data row1 col0" >1620</td>
#       <td id="T_0ad53_row1_col1" class="data row1 col1" >203</td>
#       <td id="T_0ad53_row1_col2" class="data row1 col2" >392</td>
#       <td id="T_0ad53_row1_col3" class="data row1 col3" >651</td>
#       <td id="T_0ad53_row1_col4" class="data row1 col4" >2236</td>
#     </tr>
#     <tr>
#       <th id="T_0ad53_level0_row2" class="row_heading level0 row2" >Quant MDP</th>
#       <td id="T_0ad53_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0ad53_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0ad53_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0ad53_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_0ad53_row2_col4" class="data row2 col4" >3</td>
#     </tr>
#   </tbody>
# </table>
